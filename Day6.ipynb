# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedaslanshas/codomax-ds-internship/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
print(df.shape)
print(df.head())
print(df.tail())
print(df.columns.tolist())
print(df.dtypes)
df.info()
df.describe()
df.describe(include="object")
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print(df.isnull().sum())
print(df.isnull().sum()/ len(df)*100)

print(df.duplicated().sum())

print(df["Sex"].unique())
print(df["Sex"].value_counts())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64
# 0
# ['male' 'female']
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df =df.rename(columns={"Sex":"gender"})

df_subset = df[["Name","Age","gender","Survived"]]

df_sorted = df.sort_values(by="Age", ascending=False)
print(df_sorted.head())
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#     gender   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630   male  80.0      0      0     27042  30.0000   A23        S
# 851   male  74.0      0      0    347060   7.7750   NaN        S
# 493   male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96    male  71.0      0      0  PC 17754  34.6542    A5        C
# 116   male  70.5      0      0    370369   7.7500   NaN        Q

# %%
print("Shape:", df.shape)
df.head(5)
# Out:
# Shape: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
missing_pct = (df.isnull().sum() / len(df)) * 100
missing_pct[missing_pct > 0]
# Out:
# Age         19.865320
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.sort_values(by="Fare", ascending=True).head(5)
# Out:
#      PassengerId  Survived  Pclass                              Name gender  \
# 815          816         0       1                  Fry, Mr. Richard   male
# 806          807         0       1            Andrews, Mr. Thomas Jr   male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming   male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"   male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr   male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 815   NaN      0      0  112058   0.0  B102        S
# 806  39.0      0      0  112050   0.0   A36        S
# 413   NaN      0      0  239853   0.0   NaN        S
# 481   NaN      0      0  239854   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S
